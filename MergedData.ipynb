# %%
import pandas as pd

#replace <path on you computer to file, e.g. C:\....> with the path to the file 
df = pd.read_csv(r'./train.csv')  
df2 = pd.read_csv(r'./test.csv')
# Out:
# C:\Users\20201158\AppData\Local\Temp\ipykernel_21596\3701430870.py:4: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'./train.csv')

# %%
frames = [df, df2]
merged_data = pd.concat(frames)

# %%
print(frames)
# Out:
# [            ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %%
missing = df.isnull().sum()
print(missing)
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# ...

# %%
merged_data['Occupation'].unique()
# Out:
# array(['Scientist', '_______', 'Teacher', 'Engineer', 'Entrepreneur',
#        'Developer', 'Lawyer', 'Media_Manager', 'Doctor', 'Journalist',
#        'Manager', 'Accountant', 'Musician', 'Mechanic', 'Writer',
#        'Architect'], dtype=object)

# %%
results = merged_data.loc[merged_data['Occupation'] =='_______' ]
results
# Out:
#             ID Customer_ID      Month              Name  Age          SSN  \
# 8       0x160e  CUS_0x21b1    January   Rick Rothackerj  28_  004-07-5839
# 16      0x161a  CUS_0x2dbc    January            Langep   34  486-85-3974
# 18      0x161c  CUS_0x2dbc      March            Langep   34  486-85-3974
# 20      0x161e  CUS_0x2dbc        May            Langep   34  486-85-3974
# 29      0x162b  CUS_0xb891       June            Jasond   55    #F%$D@*&8
# ...        ...         ...        ...               ...  ...          ...
# 49948  0x25f5e  CUS_0x4986  September   Charles Abbotta   34  971-61-8388
# 49963  0x25f85  CUS_0x2654   December               enj   38  647-67-8889
# 49967  0x25f91  CUS_0xb11c   December    Yinka Adegokej   39  546-94-4789
# 49971  0x25f9d  CUS_0xad4f   December  Sabina Zawadzkig   48  226-45-0652
# 49994  0x25fe4  CUS_0x8600   November    Sarah McBridec   29  031-35-0942
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# ...
